# %%
import pandas as pd
df= pd.read_csv('CC GENERAL.csv',",")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df=df.drop('CUST_ID',1)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-a55be3fad273> in <module>
# ----> 1 df=df.drop('CUST_ID',1)
#       2
#       3 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.dropna(thresh=2)

df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.dropna(axis=0, how='any',thresh=None, inplace=False)
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 4      817.714335           1.000000      16.00             16.00
# 5     1809.828751           1.000000    1333.28              0.00
# ...           ...                ...        ...               ...
# 8943     5.871712           0.500000      20.90             20.90
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
from sklearn.cluster import AgglomerativeClustering 
model=AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='complete')
clust_labels=model.fit_predict(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-5101be0f2d09> in <module>
#       1 from sklearn.cluster import AgglomerativeClustering
#       2 model=AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='complete')
# ----> 3 clust_labels=model.fit_predict(df)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py in fit_predict(self, X, y)
#     944             Cluster labels.
#     945         """
# --> 946         return super().fit_predict(X, y)
#     947
#     948
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     581         # non-optimized default implementation; override when a better
#     582         # method is possible for a given clustering algorithm
# --> 583         self.fit(X)
#     584         return self.labels_
#     585
#
# ...

# %%
agglomerative=pd.DataFrame(clust_labels)
agglomerative
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-af898d03d9ba> in <module>
# ----> 1 agglomerative=pd.DataFrame(clust_labels)
#       2 agglomerative
#
# NameError: name 'clust_labels' is not defined

# %%
import matplotlib.pyplot as plt
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (df ["BALANCE_FREQUENCY"] , df ["PURCHASES"] , c= agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("BALANCE_FREQUENCY")
ax.set_ylabel("PURCHASES")
plt.colorbar(scatter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-bce5687b3ae4> in <module>
#       2 fig =plt.figure()
#       3 ax = fig.add_subplot(111)
# ----> 4 scatter = ax.scatter (df ["BALANCE_FREQUENCY"] , df ["PURCHASES"] , c= agglomerative[0], s=50)
#       5 ax.set_title("Agglomerative Clutering")
#       6 ax.set_xlabel("BALANCE_FREQUENCY")
#
# NameError: name 'agglomerative' is not defined

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(df, method="complete"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-577391a38484> in <module>
#       3 plt.figure(figsize=(10,7))
#       4 plt.title("Customer Dendrograms")
# ----> 5 dend=shc.dendrogram(shc.linkage(df, method="complete"))
#
# ~\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1063
#    1064     if not np.all(np.isfinite(y)):
# -> 1065         raise ValueError("The condensed distance matrix must contain only "
#    1066                          "finite values.")
#    1067
#
# ValueError: The condensed distance matrix must contain only finite values.

# %%
from sklearn.cluster import KMeans  #Importing our clustering algorithm: KMeans
kmeans=KMeans(n_clusters=5, random_state=0)  #Cluster our data by choosing 5 as number of clusters
kmeans.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-f5518dc6f2d7> in <module>
#       1 from sklearn.cluster import KMeans  #Importing our clustering algorithm: KMeans
#       2 kmeans=KMeans(n_clusters=5, random_state=0)  #Cluster our data by choosing 5 as number of clusters
# ----> 3 kmeans.fit(df)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
# ...

# %%
labels=pd.DataFrame(kmeans.labels_)
labels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-d894cfb2cfd2> in <module>
# ----> 1 labels=pd.DataFrame(kmeans.labels_)
#       2 labels
#
# AttributeError: 'KMeans' object has no attribute 'labels_'

# %%
kmeans.predict(data)
print(kmeans.cluster_centers_)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-70-139975bfda24> in <module>
# ----> 1 kmeans.predict(data)
#       2 print(kmeans.cluster_centers_)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in predict(self, X, sample_weight)
#    1152             Index of the cluster each sample belongs to.
#    1153         """
# -> 1154         check_is_fitted(self)
#    1155
#    1156         X = self._check_test_data(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1039
# ...

# %%
plt.scatter(data["Annual Income (k$)"][data.label == 0],          
            data["Spending Score (1-100)"][data.label == 0],s=80,c='magenta',label='Careful')
plt.scatter(data["Annual Income (k$)"][data.label == 1],
           data["Spending Score (1-100)"][data.label == 1],s=80,c='yellow',label='Standard')
plt.scatter(data["Annual Income (k$)"][data.label == 2],
           data["Spending Score (1-100)"][data.label == 2],s=80,c='green',label='Target')
plt.scatter(data["Annual Income (k$)"][data.label == 3], 
           data["Spending Score (1-100)"][data.label == 3],s=80,c='cyan',label='Careless')
plt.scatter(data["Annual Income (k$)"][data.label == 4], 
           data["Spending Score (1-100)"][data.label == 4],s=80,c='burlywood',label='Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income(k$)')
plt.ylabel('Spending Score(1-100')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-50e100c42670> in <module>
# ----> 1 plt.scatter(data["Annual Income (k$)"][data.label == 0],
#       2             data["Spending Score (1-100)"][data.label == 0],s=80,c='magenta',label='Careful')
#       3 plt.scatter(data["Annual Income (k$)"][data.label == 1],
#       4            data["Spending Score (1-100)"][data.label == 1],s=80,c='yellow',label='Standard')
#       5 plt.scatter(data["Annual Income (k$)"][data.label == 2],
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
plt.scatter(data["BALANCE_FREQUENCY"][data.label == 0],          
            data["PURCHASES"][data.label == 0],s=80,c='magenta',label='Careful')
plt.scatter(data["BALANCE_FREQUENCY"][data.label == 1],
           data["PURCHASES"][data.label == 1],s=80,c='yellow',label='Standard')
plt.scatter(data["BALANCE_FREQUENCY"][data.label == 2],
           data["PURCHASES"][data.label == 2],s=80,c='green',label='Target')
plt.scatter(data["BALANCE_FREQUENCY"][data.label == 3], 
           data["PURCHASES"][data.label == 3],s=80,c='cyan',label='Careless')
plt.scatter(data["BALANCE_FREQUENCY"][data.label == 4], 
           data["PURCHASES"][data.label == 4],s=80,c='burlywood',label='Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('BALANCE_FREQUENCY')
plt.ylabel('PURCHASES')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'BALANCE_FREQUENCY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-dbcfec92415f> in <module>
# ...
